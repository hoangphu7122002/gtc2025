# %%
import pandas as pd
import os
from tqdm import tqdm

# %%
len_ds = len(os.listdir('/workspace/nemo_datasets/add_id'))
for i in tqdm(range(len_ds)):
#     if f'{i}.parquet' in os.listdir('/workspace/nemo_datasets/phu_classifier_filtering/'):
#         continue
    df_result = pd.read_parquet(f'/workspace/nemo_datasets/heuristic_filtering/data/hq.parquet/part.{i}.parquet', engine='pyarrow').head(1)
    print(df_result.iloc[0]['id'])
#     print(df_result.head(5))
#     df_now = pd.read_parquet(f'/workspace/nemo_datasets/classifier_filtering/data/hq.parquet/part.{i}.parquet', engine='pyarrow')
# Out:
#   0%|▎                                                                                  | 1/256 [00:07<31:39,  7.45s/it]
# VI_open-0000000000
#   1%|▋                                                                                  | 2/256 [00:15<33:12,  7.84s/it]
# VI_open-0000455194
#   1%|▉                                                                                  | 3/256 [00:22<31:16,  7.42s/it]
# VI_open-0000910388
#   2%|█▎                                                                                 | 4/256 [00:30<31:40,  7.54s/it]
# VI_open-0001365583
#   2%|█▌                                                                                 | 5/256 [00:38<31:56,  7.63s/it]
# VI_open-0001820779
#   2%|█▉                                                                                 | 6/256 [00:45<31:58,  7.68s/it]
# VI_open-0002275971
#   3%|██▎                                                                                | 7/256 [00:53<32:10,  7.75s/it]
# VI_open-0002731165
#   3%|██▌                                                                                | 8/256 [01:00<31:15,  7.56s/it]
# VI_open-0003186358
#   4%|██▉                                                                                | 9/256 [01:08<31:35,  7.67s/it]
# VI_open-0003641553
#   4%|███▏                                                                              | 10/256 [01:15<30:34,  7.46s/it]
# VI_open-0004096747
#   4%|███▌                                                                              | 11/256 [01:23<30:16,  7.41s/it]
# VI_open-0004551941
#   5%|███▊                                                                              | 12/256 [01:31<30:58,  7.62s/it]
# VI_open-0005007135
